# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

diabetes_data = pd.read_csv('/content/drive/My Drive/diabetes.csv')
diabetes_data
# Out:
# Mounted at /content/drive
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
data = list(zip(diabetes_data['Pregnancies'],diabetes_data['Glucose'],diabetes_data['BloodPressure'],diabetes_data['SkinThickness']))
print(data)
# Out:
# [(6, 148, 72, 35), (1, 85, 66, 29), (8, 183, 64, 0), (1, 89, 66, 23), (0, 137, 40, 35), (5, 116, 74, 0), (3, 78, 50, 32), (10, 115, 0, 0), (2, 197, 70, 45), (8, 125, 96, 0), (4, 110, 92, 0), (10, 168, 74, 0), (10, 139, 80, 0), (1, 189, 60, 23), (5, 166, 72, 19), (7, 100, 0, 0), (0, 118, 84, 47), (7, 107, 74, 0), (1, 103, 30, 38), (1, 115, 70, 30), (3, 126, 88, 41), (8, 99, 84, 0), (7, 196, 90, 0), (9, 119, 80, 35), (11, 143, 94, 33), (10, 125, 70, 26), (7, 147, 76, 0), (1, 97, 66, 15), (13, 145, 82, 19), (5, 117, 92, 0), (5, 109, 75, 26), (3, 158, 76, 36), (3, 88, 58, 11), (6, 92, 92, 0), (10, 122, 78, 31), (4, 103, 60, 33), (11, 138, 76, 0), (9, 102, 76, 37), (2, 90, 68, 42), (4, 111, 72, 47), (3, 180, 64, 25), (7, 133, 84, 0), (7, 106, 92, 18), (9, 171, 110, 24), (7, 159, 64, 0), (0, 180, 66, 39), (1, 146, 56, 0), (2, 71, 70, 27), (7, 103, 66, 32), (7, 105, 0, 0), (1, 103, 80, 11), (1, 101, 50, 15), (5, 88, 66, 21), (8, 176, 90, 34), (7, 150, 66, 42), (1, 73, 50, 10), (7, 187, 68, 
# ...

# %%
y = diabetes_data.Outcome
print(y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(data,y,test_size=0.2,random_state=10)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
y_predict_train=model.predict(X_train)
accuracy_score(y_test,y_predict)
# Out:
# 0.6298701298701299

# %%
accuracy_score(y_train,y_predict_train)
# Out:
# 0.8224755700325733

# %%
print( accuracy_score(y_test,y_predict))
# Out:
# 0.6298701298701299

# %%
print(classification_report(y_test,y_predict))

# %%
confusion_matrix(y_test,y_predict)
# Out:
# array([[76, 19],
#        [38, 21]])
