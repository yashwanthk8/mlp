# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data = pd.read_csv('/content/drive/My Drive/iris.csv')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  target
# 0           5.1          3.5           1.4          0.2       0
# 1           4.9          3.0           1.4          0.2       0
# 2           4.7          3.2           1.3          0.2       0
# 3           4.6          3.1           1.5          0.2       0
# 4           5.0          3.6           1.4          0.2       0

# %%
data.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  target
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2

# %%
data.shape
# Out:
# (150, 5)

# %%
data.target.unique()
# Out:
# array([0, 1, 2])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   target        150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width      target
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.054000      3.758667     1.198667    1.000000
# std        0.828066     0.433594      1.764420     0.763161    0.819232
# min        4.300000     2.000000      1.000000     0.100000    0.000000
# 25%        5.100000     2.800000      1.600000     0.300000    0.000000
# 50%        5.800000     3.000000      4.350000     1.300000    1.000000
# 75%        6.400000     3.300000      5.100000     1.800000    2.000000
# max        7.900000     4.400000      6.900000     2.500000    2.000000

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# target          0
# dtype: int64

# %%
from collections import Counter
Counter(data.target)
# Out:
# Counter({0: 50, 1: 50, 2: 50})

# %%
data.target.value_counts()
# Out:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
X = data.iloc[:,:-1]
y = data[['target']]

# %%
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y.head()
# Out:
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=10,test_size=0.2)

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
model = SVC() # c=1.0, kernel=rbf
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.9666666666666667

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      0.92      0.96        13
#            2       0.88      1.00      0.93         7
#
#     accuracy                           0.97        30
#    macro avg       0.96      0.97      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %%
model = SVC(C=0.1)# c=0.1
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8666666666666667

# %%
confusion_matrix(y_test,y_predict)
# Out:
# array([[10,  0,  0],
#        [ 0,  9,  4],
#        [ 0,  0,  7]])

# %%
model = SVC(C=10)# c=10
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9666666666666667

# %%
model = SVC(C=100)# c=100
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 1.0

# %%
model = SVC(C=1000)# c=100
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9666666666666667

# %%
model = SVC(C=10000)# c=100
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9666666666666667

# %%
model = SVC(gamma=0.01)# gamma=0.01
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9333333333333333

# %%
model = SVC(gamma=0.1)# gamma=0.1
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9666666666666667

# %%
model = SVC(gamma=1)# gamma=1
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9666666666666667

# %%
model = SVC(gamma=100)# gamma=1
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.5333333333333333

# %%
model = SVC(gamma=1000)# gamma=1
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.23333333333333334

# %%
model = SVC(C=100,gamma=0.1,kernel='linear')# gamma=1
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 1.0

# %%
model = SVC(kernel='linear')# gamma=1
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9666666666666667

# %%
model = SVC(kernel='poly')
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9666666666666667

# %%
import matplotlib.pyplot as plt
df0 = data[:50]
df1 = data[50:100]
df2 = data[100:150]

# %%
x = data.iloc[:100,:2]
y = data.target[:100]

# %%
plt.scatter(df0['sepal_length'],df0['sepal_width'],color='green',marker='+')
plt.scatter(df2['sepal_length'],df2['sepal_width'],color='red',marker='*')
plt.scatter(df1['sepal_length'],df1['sepal_width'],color='blue',marker='*')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Assuming your data has three features: sepal_length, sepal_width, and petal_length
# If you have different features, replace them accordingly
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plotting the data points with smaller marker size
ax.scatter(df0['sepal_length'], df0['sepal_width'], df0['petal_length'], color='green', marker='+', s=100)
ax.scatter(df1['sepal_length'], df1['sepal_width'], df1['petal_length'], color='blue', marker='*', s=100)
ax.scatter(df2['sepal_length'], df2['sepal_width'], df2['petal_length'], color='red', marker='*', s=100)

# Setting labels for each axis
ax.set_xlabel('Sepal Length')
ax.set_ylabel('Sepal Width')
ax.set_zlabel('Petal Length')

plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Assuming your data has three features: sepal_length, sepal_width, and petal_length
# If you have different features, replace them accordingly
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plotting the data points
ax.scatter(df0['sepal_length'], df0['sepal_width'], df0['petal_length'], color='green', marker='+', s=30)
ax.scatter(df1['sepal_length'], df1['sepal_width'], df1['petal_length'], color='blue', marker='*', s=30)
ax.scatter(df2['sepal_length'], df2['sepal_width'], df2['petal_length'], color='red', marker='*', s=30)

# Setting labels for each axis
ax.set_xlabel('Sepal Length')
ax.set_ylabel('Sepal Width')
ax.set_zlabel('Petal Length')

# Setting the viewing range for each axis (zooming)
ax.set_xlim([4.5,7])  # Set the limits for the x-axis
ax.set_ylim([-6,6])  # Set the limits for the y-axis
ax.set_zlim([3,6])  # Set the limits for the z-axis

plt.show()

# %%
plt.scatter(df0['petal_length'],df0['petal_width'],color='green',marker='+')
plt.scatter(df2['petal_length'],df2['petal_width'],color='red',marker='*')
plt.scatter(df1['petal_length'],df1['petal_width'],color='blue',marker='*')

# %%
import seaborn as sns
sns.pairplot(data,hue="target", palette="cool")

# %%
import seaborn as sns
sns.pairplot(data,hue ="target",palette="rainbow")
